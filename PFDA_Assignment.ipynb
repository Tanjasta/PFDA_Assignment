# %% [markdown]
# # Programming for Data Analysis Assignment
# ### Tatjana Staunton

# %% [markdown]
# Task for this Assignment is create a data set by simulating a real-world phenomenon.
#
# • Choose a real-world phenomenon that can be measured and for which you could
# collect at least one-hundred data points across at least four different variables.
#
# • Investigate the types of variables involved, their likely distributions, and their
# relationships with each other.
#
# • Synthesise/simulate a data set as closely matching their properties as possible.
#
# • Detail your research and implement the simulation in a Jupyter notebook – the
# data set itself can simply be displayed in an output cell within the notebook.

# %% [markdown]
# ### Description/Overview of the project

# %% [markdown]
# This project will present a simulation of a dataset representing the relationship between study load, sleep quality, academic performance, and stress levels of students. To achieve this, a set of data points representing real-life scenarios and patterns observed in real-world situations will be generated. This involves creating a dataset that reflects the the intricate interplay between study load, sleep quality, academic performance, and stress levels.
#
# **Research Objective:**
# The primary objective of this study is to investigate a real-life data that represents the complex relationship between study load, sleep quality, academic performance, and stress levels among students.
#
# **Methodology:**
# To accomplish this, an extensive online research approach has been employed to investigate existing datasets and research papers. The objective is to gather real-world data that mirrors the authentic scenarios and patterns observed in the context of study load, sleep quality, academic performance, and stress levels.
#
# **Literature Review:**
# The research will involve an extensive literature review to identify and analyse relevant studies conducted by other researchers. This process will include summarising key findings, methodologies used, and any gaps or controversies in the existing literature.
#
# **Research Design:**
# Since there is no new data collection, the research design will focus on the analysis of existing studies and data sets. The goal is to draw connections, identify trends, and contribute to a comprehensive understanding of the subject matter.
#
# **Data Analysis (Literature Synthesis):**
# Instead of statistical analysis, the research will involve synthesising information from various sources. This might include identifying common themes, discrepancies, or emerging patterns across different studies.
#
# **Ethical Considerations:**
# Ethical considerations will center around the proper citation and acknowledgment of the original research papers. It is crucial to respect intellectual property rights and give credit to the researchers whose work forms the basis of the study.
#
# **Conclusion:**
# The study will conclude with a summary of the collective insights gained from the literature review. This may involve proposing potential avenues for future research, addressing any unresolved questions, and providing a comprehensive overview of the current state of knowledge on the topic.

# %% [markdown]
# #### Literature Review
#
# A "Student Stress Factors: A Comprehensive Analysis" (https://www.kaggle.com/datasets/rxnach/student-stress-factors-a-comprehensive-analysis/data?select=StressLevelDataset.csv) is a dataset examining the stress factors experienced by students provides a comprehensive perspective on the challenges they face. Encompassing psychological elements such as anxiety and self-esteem, along with academic pressures and social dynamics, this compilation offers a well-rounded understanding of the difficulties confronted by contemporary students.
#
# According to the "Relationship between poor quality sleep, excessive daytime sleepiness and low academic performance in medical students"(https://www.dovepress.com/relationship-between-poor-quality-sleep-excessive-daytime-sleepiness-a-peer-reviewed-fulltext-article-AMEP), poor sleep quality is assosiated with poor academic performance. A study of 457 medical students was carried out, employing a cross-sectional approach.Findigs showed that numerous studies have indicated a positive correlation between insufficient sleep duration (less than 7–8 hours per night), sleep patterns, and wake habits, and lower academic performance. In councusion, low-quality sleep was found to be associated with poor academic performance by the end of the academic year among medical students.
#
# Futhermore, "The relationship between sleep quality, stress, and academic performance among medical students" journal
# (https://journals.lww.com/jfcm/fulltext/2020/27010/the_relationship_between_sleep_quality,_stress,.4.aspx) reported similar findings. The study reported a relationship between sleep quality, stress, and academic performance.According to the paper "Poor quality of sleep was significantly associated with elevated mental stress levels".
#
# A study conducted on 401 studens, (https://bmcnurs.biomedcentral.com/articles/10.1186/s12912-021-00635-x) revieled that poor sleeping has affect on academic performance. According to "Relationship between sleep habits and academic performance in university Nursing students" poor sleep habits, such as short sleep patterns are associated with a greater risk of poor academic performance.
#
# The "Sleep Duration the Night before an Exam and Its Relationship to Students’ Exam Scores" (https://www.researchgate.net/publication/303040214_Sleep_Duration_the_Night_before_an_Exam_and_Its_Relationship_to_Students'_Exam_Scores)  study suggests that  that sufficient sleep during the night before an exam is connected to improved performance on the exam.
#
# Aditionaly, research shows that stress levels afect quality of academic performance. According to "Stress and Its Relationship with the Academic Performance of Higher Institution Students" (https://www.researchgate.net/publication/348500008_Stress_and_Its_Relationship_with_the_Academic_Performance_of_Higher_Institution_Students#:) the analysis revealed a negative correlation between stress levels and academic performance, indicating that higher stress levels were associated with lower academic achievements.
#
# According to the publication "The Relationship Between Anxiety and Sleep Quality Among Medical Students" (https://link.springer.com/article/10.1007/s41782-023-00242-7) there is a mild correlation between poor sleep quality and elevated anxiety levels. Addressing and managing anxiety in students can contribute to enhancements in both their academic and overall quality of life.

# %% [markdown]
# #### Research Design
#
# With insights gained from the literature review and analysis of existing studies and data sets, the "Student Stress Factors: A Comprehensive Analysis" will be consulted for the data need for this project. To be more presised the StressLevelDataset.csv. and findings on research Github Repository (https://github.com/Chhabii/MHM_b/blob/master/stresslevel.ipynb).
#
# The dataset contains approximately 20 features that have the biggest impact on a student's stress levels. These features are chosen scientifically, taking into account five key factors: Psychological, Physiological, Social, Environmental, and Academic.
#
# Description of each of the factors:
#
# 1) Anxiety : range from 0 to 21, Measure : GAD-7
# 2) Self-esteem : range 0 to 30, Measure: Rosenberg Self Esteem Scale
# 3) Mental Health History : 0 if no mental health history, 1 if mental health history
# 4) Depression : range 0 to 27, Measure: Patient Health Questionnaire (PHQ-9)
# 5) Other features  range from 0 to 5 considering 0,1 to be low, 2,3 to be mid, and 4,5 to be high (https://www.kaggle.com/datasets/rxnach/student-stress-factors-a-comprehensive-analysis/discussion/451616).

# %%
import pandas as pd
df = pd.read_csv("StressLevelDataset.csv")
df
# Out:
#       anxiety_level  self_esteem  mental_health_history  depression  headache  \
# 0                14           20                      0          11         2
# 1                15            8                      1          15         5
# 2                12           18                      1          14         2
# 3                16           12                      1          15         4
# 4                16           28                      0           7         2
# ...             ...          ...                    ...         ...       ...
# 1095             11           17                      0          14         3
# 1096              9           12                      0           8         0
# 1097              4           26                      0           3         1
# 1098             21            0                      1          19         5
# 1099             18            6                      1          15         3
#
# ...

# %%
df.describe()
# Out:
#        anxiety_level  self_esteem  mental_health_history   depression  \
# count    1100.000000  1100.000000            1100.000000  1100.000000
# mean       11.063636    17.777273               0.492727    12.555455
# std         6.117558     8.944599               0.500175     7.727008
# min         0.000000     0.000000               0.000000     0.000000
# 25%         6.000000    11.000000               0.000000     6.000000
# 50%        11.000000    19.000000               0.000000    12.000000
# 75%        16.000000    26.000000               1.000000    19.000000
# max        21.000000    30.000000               1.000000    27.000000
#
#           headache  blood_pressure  sleep_quality  breathing_problem  \
# count  1100.000000     1100.000000    1100.000000        1100.000000
# mean      2.508182        2.181818       2.660000           2.753636
# std       1.409356        0.833575       1.548383           1.400713
# ...

# %%
df.dtypes
# Out:
# anxiety_level                   int64
# self_esteem                     int64
# mental_health_history           int64
# depression                      int64
# headache                        int64
# blood_pressure                  int64
# sleep_quality                   int64
# breathing_problem               int64
# noise_level                     int64
# living_conditions               int64
# safety                          int64
# basic_needs                     int64
# academic_performance            int64
# study_load                      int64
# teacher_student_relationship    int64
# future_career_concerns          int64
# social_support                  int64
# peer_pressure                   int64
# extracurricular_activities      int64
# bullying                        int64
# stress_level                    int64
# dtype: object

# %%
df[['study_load','sleep_quality', 'academic_performance', 'stress_level']]
# Out:
#       study_load  sleep_quality  academic_performance  stress_level
# 0              2              2                     3             1
# 1              4              1                     1             2
# 2              3              2                     2             1
# 3              4              1                     2             2
# 4              3              5                     4             1
# ...          ...            ...                   ...           ...
# 1095           2              3                     2             1
# 1096           1              0                     0             2
# 1097           1              5                     5             0
# 1098           5              1                     2             2
# 1099           4              0                     3             2
#
# [1100 rows x 4 columns]

# %%
df[['study_load','sleep_quality', 'academic_performance', 'stress_level']].dtypes
# Out:
# study_load              int64
# sleep_quality           int64
# academic_performance    int64
# stress_level            int64
# dtype: object

# %%
df[['study_load','sleep_quality', 'academic_performance', 'stress_level']].describe()
# Out:
#         study_load  sleep_quality  academic_performance  stress_level
# count  1100.000000    1100.000000           1100.000000   1100.000000
# mean      2.621818       2.660000              2.772727      0.996364
# std       1.315781       1.548383              1.414594      0.821673
# min       0.000000       0.000000              0.000000      0.000000
# 25%       2.000000       1.000000              2.000000      0.000000
# 50%       2.000000       2.500000              2.000000      1.000000
# 75%       3.000000       4.000000              4.000000      2.000000
# max       5.000000       5.000000              5.000000      2.000000

# %% [markdown]
# #### Data Analysis (Literature Synthesis)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
np.random.seed(50)  

# Number of data points
n = 100

# Generate synthetic data
study_load = np.random.normal(loc=2.6, scale=1.3, size=n)
sleep_quality = np.random.normal(loc=2.6, scale=1.5, size=n)
stress_level = np.random.normal(loc=1, scale=0.8, size=n)
academic_performance = np.random.normal(loc=2.7, scale=1.4, size=n)

# %%
#Creating dataframe using Pandas
data = pd.DataFrame({
    'Study Load': study_load,
    'Sleep Quality': sleep_quality,
    'Stress Level': stress_level,
    'Academic Performance': academic_performance
})

# %%
# Create a plot with all variables on the same axes
plt.figure(figsize=(10, 6))  # Adjust the figure size if needed

# Plot each variable
plt.plot(data['Study Load'], label='Study Load')
plt.plot(data['Sleep Quality'], label='Sleep Quality')
plt.plot(data['Stress Level'], label='Stress Level')
plt.plot(data['Academic Performance'], label='Academic Performance')

# Add labels and title
plt.xlabel('Data Points')
plt.ylabel('Values')
plt.title('Synthetic Data Variables')
plt.legend()

# Show the plot
plt.show()

# %%
# Importing seaborn library
import seaborn as sns

# Pairplot for a quick overview of variable relationships
sns.pairplot(data)
plt.show()

# %%
# %matplotlib inline
sns.pairplot(data, hue='Academic Performance')
plt.show()

# %%
import seaborn as sns

sns.kdeplot(data)

plt.show()

# %%
data.head()
# Out:
#    Study Load  Sleep Quality  Stress Level  Academic Performance
# 0    0.571542       2.212777      1.452017              3.375141
# 1    2.559729       2.670734      1.045812              3.883750
# 2    1.792793       1.959402      1.193260              4.307055
# 3    0.696045       2.418151      1.388938              3.118796
# 4    4.435530       2.347138      0.709253              4.237299

# %%
data.tail()
# Out:
#     Study Load  Sleep Quality  Stress Level  Academic Performance
# 95    0.901195       5.257531      1.352917              3.154028
# 96    1.443301       1.151644      0.133240              1.737709
# 97    2.606848       4.655531      0.503258              1.766475
# 98    3.726352       1.749082      1.236505              1.183323
# 99    1.903804       0.996262      0.899972              1.421904

# %%
data.to_csv('simulated_dataset.csv', index=False)

# %% [markdown]
# #### References
#
# https://vlegalwaymayo.atu.ie/course/view.php?id=8876
#
# https://realpython.com/python-data-types/
#
# https://numpy.org/doc/stable/user/basics.types.html
#
# https://docs.python.org/3/library/stdtypes.html
#
# https://www.skytowner.com/explore/describing_certain_columns_of_a_dataframe_in_pandas#:~:text=To%20describe%20certain%20columns%2C%20
#
# https://www.kaggle.com/datasets/rxnach/student-stress-factors-a-comprehensive-analysis/data?select=StressLevelDataset.csv
#
# https://www.geeksforgeeks.org/how-to-create-a-seaborn-correlation-heatmap-in-python/
#
# https://www.researchgate.net/publication/303040214_Sleep_Duration_the_Night_before_an_Exam_and_Its_Relationship_to_Students'_Exam_Scores
#
# https://www.mdpi.com/2227-9032/11/17/2389
#
# https://bmcnurs.biomedcentral.com/articles/10.1186/s12912-021-00635-x
#
# https://www.dovepress.com/relationship-between-poor-quality-sleep-excessive-daytime-sleepiness-a-peer-reviewed-fulltext-article-AMEP
#
# https://journals.lww.com/jfcm/fulltext/2020/27010/the_relationship_between_sleep_quality,_stress,.4.aspx
#
# https://www.researchgate.net/publication/348500008_Stress_and_Its_Relationship_with_the_Academic_Performance_of_Higher_Institution_Students#:
#
# https://github.com/Chhabii/MHM_b
#
# https://github.com/Chhabii/MHM_b/blob/master/stresslevel.ipynb
#
# https://seaborn.pydata.org/generated/seaborn.pairplot.html
#
# https://seaborn.pydata.org/generated/seaborn.kdeplot.html
